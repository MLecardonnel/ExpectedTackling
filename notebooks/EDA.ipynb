# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Games

# %%
df_games = pd.read_csv('../data/raw_data/games.csv')
profile = ProfileReport(df_games, title="Profiling Report")
profile.to_widgets()

# %% [markdown]
# ## Players

# %%
df_players = pd.read_csv('../data/raw_data/players.csv')
profile = ProfileReport(df_players, title="Profiling Report")
profile.to_widgets()

# %% [markdown]
# ## Plays

# %%
df_plays = pd.read_csv('../data/raw_data/plays.csv')
profile = ProfileReport(df_plays, title="Profiling Report")
profile.to_widgets()

# %% [markdown]
# ## Tackles

# %%
df_tackles = pd.read_csv('../data/raw_data/tackles.csv')
profile = ProfileReport(df_tackles, title="Profiling Report")
profile.to_widgets()

# %% [markdown]
# ## Tracking weeks

# %%
df_tracking = pd.concat([pd.read_csv(f"../data/raw_data/tracking_week_{i}.csv") for i in range(1,10)])
profile = ProfileReport(df_tracking, title="Profiling Report")
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\matt0\Documents\Projets\ExpectedTackling\.venv\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
print(df_tracking.gameId.nunique())
print(df_tracking.playId.nunique())
print(df_tracking.nflId.nunique())
# Out:
# 136
# 3974
# 1683

# %%
df_tracking.jerseyNumber.unique()
# Out:
# array([76., 45., 99., 60., 14.,  2.,  5., 54., 94., 73.,  6., 17., 24.,
#        26., 88., 91., 33., 71., 13.,  4., 79., 53., nan, 15., 22., 58.,
#        41., 80., 20., 52., 89.,  9., 40., 23., 21.,  1., 92., 10., 49.,
#        70., 55.,  7., 65., 27., 30., 50., 18., 47., 97., 57., 93., 28.,
#         3., 19., 96., 75., 68., 56., 32., 12., 63.,  8., 67., 84., 46.,
#        98., 29., 74., 78., 51., 82., 95., 11., 83., 35., 34., 37., 86.,
#        48., 66., 90., 72., 43., 85., 25., 77., 38., 44., 81., 31., 64.,
#        69., 62., 61., 39., 59., 16., 42., 87., 36.])

# %%
pd.merge(df_tracking[['nflId', 'jerseyNumber']], df_players[['nflId', 'position']], on='nflId', how='left').groupby(['jerseyNumber', 'position']).count().transpose()
# Out:
# jerseyNumber   1.0                               2.0                      \
# position         CB    FS     QB     RB     WR     CB   OLB     QB    RB
# nflId         32204  3004  86518  17072  90129  51335  5636  30587  8145
#
# jerseyNumber                 3.0                                            \
# position         SS     WR     CB     FS    ILB     QB    RB     SS     WR
# nflId         17595  55854  37624  15322  15952  13433  4885  53848  26226
#
# jerseyNumber   4.0                                            5.0         \
# position         CB    DE    FS     QB     RB     SS     WR     CB    DE
# nflId         25139  6688  6299  38574  10853  20616  20487  33943  4030
#
# jerseyNumber                                           6.0                 \
# position         FS   MLB    OLB    QB     SS     WR     CB     FS    ILB
# nflId         29371  3324  22235  6576  17535  29905  28571  30553  15204
#
# ...
