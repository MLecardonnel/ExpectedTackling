# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pycaret.classification import ClassificationExperiment
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

from expected_tackling.data.mott_features import sample_training_data

# %% [markdown]
# ## Import Data

# %%
mott_features_data = pd.read_csv("../data/features_mott.csv", index_col=[0,1,2,3,4])
mott_features_data.head(5)
# Out:
#                                                       ott  \
# gameId     playId nflId   opportunityId frameId
# 2022090800 56     38577.0 0             17.0     0.191902
#                   41239.0 0             7.0      0.000860
#                   42816.0 0             11.0     0.001351
#                   43294.0 0             18.0     1.031626
#                   43298.0 0             2.0      0.000844
#
#                                                  mean_distance_to_ball_carrier_from_peak  \
# gameId     playId nflId   opportunityId frameId
# 2022090800 56     38577.0 0             17.0                                    1.770350
#                   41239.0 0             7.0                                    13.913438
#                   42816.0 0             11.0                                   26.450194
#                   43294.0 0             18.0                                    0.670298
#                   43298.0 0             2.0                                    12.350122
#
#                                                  ball_carrier_distance_won_to_last_frame  \
# gameId     playId nflId   opportunityId frameId
# 2022090800 56     38577.0 0             17.0                                        0.00
#                   41239.0 0             7.0                                         0.36
#                   42816.0 0             11.0                                        0.00
#                   43294.0 0             18.0                                        0.00
#                   43298.0 0             2.0                                         1.15
#
#                                                  tackle_or_assist  \
# gameId     playId nflId   opportunityId frameId
# 2022090800 56     38577.0 0             17.0                  0.0
#                   41239.0 0             7.0                   0.0
#                   42816.0 0             11.0                  0.0
#                   43294.0 0             18.0                  1.0
#                   43298.0 0             2.0                   0.0
#
#                                                  pff_missedTackle
# gameId     playId nflId   opportunityId frameId
# 2022090800 56     38577.0 0             17.0                  0.0
#                   41239.0 0             7.0                   0.0
#                   42816.0 0             11.0                  0.0
#                   43294.0 0             18.0                  0.0
#                   43298.0 0             2.0                   0.0

# %%
mott_features_data.describe()
# Out:
#                 ott  mean_distance_to_ball_carrier_from_peak  \
# count  1.293950e+05                            129395.000000
# mean            inf                                10.030606
# std             NaN                                 9.823902
# min    3.487290e-11                                 0.000000
# 25%    2.555156e-03                                 2.072921
# 50%    3.033201e-02                                 6.639037
# 75%    2.715740e-01                                15.611664
# max             inf                                80.745186
#
#        ball_carrier_distance_won_to_last_frame  tackle_or_assist  \
# count                            129395.000000     129395.000000
# mean                                  4.142201          0.119804
# std                                   6.269879          0.324733
# min                                   0.000000          0.000000
# 25%                                   0.060000          0.000000
# 50%                                   1.800000          0.000000
# 75%                                   5.940000          0.000000
# max                                  84.810000          1.000000
#
#        pff_missedTackle
# count      129395.00000
# mean            0.01616
# std             0.12609
# min             0.00000
# 25%             0.00000
# 50%             0.00000
# 75%             0.00000
# max             1.00000

# %%
import numpy as np
mott_features_data[mott_features_data['ott']!=np.inf].describe()
# Out:
#                 ott  mean_distance_to_ball_carrier_from_peak  \
# count  1.293910e+05                            129391.000000
# mean   6.084030e-01                                10.030907
# std    2.399223e+00                                 9.823905
# min    3.487290e-11                                 0.010000
# 25%    2.555045e-03                                 2.073137
# 50%    3.032951e-02                                 6.639232
# 75%    2.714658e-01                                15.611720
# max    9.946929e+01                                80.745186
#
#        ball_carrier_distance_won_to_last_frame  tackle_or_assist  \
# count                            129391.000000     129391.000000
# mean                                  4.142308          0.119792
# std                                   6.269945          0.324719
# min                                   0.000000          0.000000
# 25%                                   0.060000          0.000000
# 50%                                   1.800000          0.000000
# 75%                                   5.940000          0.000000
# max                                  84.810000          1.000000
#
#        pff_missedTackle
# count     129391.000000
# mean           0.016160
# std            0.126092
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
sample_mott_features_data = sample_training_data(mott_features_data, negatives_multplier=5)

# %%
sample_mott_features_data.describe()
# Out:
#                 ott  mean_distance_to_ball_carrier_from_peak  \
# count  6.217000e+03                              6217.000000
# mean   8.659879e-01                                 8.026642
# std    2.512629e+00                                 8.555547
# min    3.609792e-09                                 0.020000
# 25%    9.929247e-03                                 2.092384
# 50%    1.886360e-01                                 4.549821
# 75%    1.075057e+00                                11.350441
# max    9.861501e+01                                61.114931
#
#        ball_carrier_distance_won_to_last_frame  tackle_or_assist  \
# count                              6217.000000       6217.000000
# mean                                  5.285955          0.093453
# std                                   7.232869          0.291090
# min                                   0.000000          0.000000
# 25%                                   0.400000          0.000000
# 50%                                   3.140000          0.000000
# 75%                                   7.330000          0.000000
# max                                  73.760000          1.000000
#
#        pff_missedTackle
# count       6217.000000
# mean           0.327328
# std            0.469276
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            1.000000

# %% [markdown]
# ## Classification

# %%
X_train, X_test, y_train, y_test = train_test_split(
    sample_mott_features_data.drop(columns=["pff_missedTackle"]), 
    sample_mott_features_data["pff_missedTackle"], 
    test_size=0.2, 
    random_state=42
)

scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)    
X_test_scaled = scaler.transform(X_test)

X_train_weights = compute_sample_weight(class_weight='balanced', y=y_train)

# %% [markdown]
# ### Catboost

# %% [markdown]
# negatives_multplier=10

# %%
model = CatBoostClassifier(max_depth=2, scale_pos_weight=5, verbose=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98      4224
#          1.0       0.71      0.87      0.78       365
#
#     accuracy                           0.96      4589
#    macro avg       0.85      0.92      0.88      4589
# weighted avg       0.97      0.96      0.96      4589
# array([[4091,  133],
#        [  47,  318]], dtype=int64)

# %% [markdown]
# negatives_multplier=5

# %%
model = CatBoostClassifier(max_depth=2, scale_pos_weight=5, verbose=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.90      0.94       820
#          1.0       0.83      0.96      0.89       424
#
#     accuracy                           0.92      1244
#    macro avg       0.91      0.93      0.92      1244
# weighted avg       0.93      0.92      0.92      1244
# array([[739,  81],
#        [ 16, 408]], dtype=int64)

# %%
model = CatBoostClassifier(max_depth=2, scale_pos_weight=2, verbose=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.98      2084
#          1.0       0.87      0.89      0.88       414
#
#     accuracy                           0.96      2498
#    macro avg       0.92      0.93      0.93      2498
# weighted avg       0.96      0.96      0.96      2498
# array([[2029,   55],
#        [  46,  368]], dtype=int64)

# %% [markdown]
# ### XGBoost

# %% [markdown]
# negatives_multplier=10

# %%
model = XGBClassifier(max_depth=2, scale_pos_weight=2)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98      4224
#          1.0       0.77      0.83      0.80       365
#
#     accuracy                           0.97      4589
#    macro avg       0.88      0.90      0.89      4589
# weighted avg       0.97      0.97      0.97      4589
# array([[4132,   92],
#        [  62,  303]], dtype=int64)

# %% [markdown]
# negatives_multplier=5

# %%
model = XGBClassifier(max_depth=2, scale_pos_weight=2)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.98      2084
#          1.0       0.87      0.89      0.88       414
#
#     accuracy                           0.96      2498
#    macro avg       0.92      0.93      0.93      2498
# weighted avg       0.96      0.96      0.96      2498
# array([[2029,   55],
#        [  44,  370]], dtype=int64)

# %% [markdown]
# negatives_multplier=2

# %%
model = XGBClassifier(max_depth=2, scale_pos_weight=2)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95       820
#          1.0       0.90      0.91      0.91       424
#
#     accuracy                           0.93      1244
#    macro avg       0.93      0.93      0.93      1244
# weighted avg       0.94      0.93      0.93      1244
# array([[777,  43],
#        [ 38, 386]], dtype=int64)

# %% [markdown]
# ### Gradient Boosting

# %% [markdown]
# negatives_multplier=20

# %%
model = GradientBoostingClassifier()
model.fit(X_train, y_train, sample_weight=X_train_weights)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.94      0.97      8343
#          1.0       0.45      0.91      0.61       428
#
#     accuracy                           0.94      8771
#    macro avg       0.72      0.93      0.79      8771
# weighted avg       0.97      0.94      0.95      8771
# array([[7875,  468],
#        [  38,  390]], dtype=int64)

# %% [markdown]
# negatives_multplier=10

# %%
model = GradientBoostingClassifier()
model.fit(X_train, y_train, sample_weight=X_train_weights)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.95      0.97      4224
#          1.0       0.62      0.91      0.74       365
#
#     accuracy                           0.95      4589
#    macro avg       0.81      0.93      0.85      4589
# weighted avg       0.96      0.95      0.95      4589
# array([[4019,  205],
#        [  33,  332]], dtype=int64)

# %% [markdown]
# negatives_multplier=5

# %%
model = GradientBoostingClassifier()
model.fit(X_train, y_train, sample_weight=X_train_weights)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96      2084
#          1.0       0.75      0.92      0.83       414
#
#     accuracy                           0.94      2498
#    macro avg       0.87      0.93      0.89      2498
# weighted avg       0.95      0.94      0.94      2498
# array([[1958,  126],
#        [  32,  382]], dtype=int64)

# %% [markdown]
# ### PyCaret

# %%
s = ClassificationExperiment()
s.setup(sample_mott_features_data, target = 'pff_missedTackle', session_id = 123, normalize = True)
# Out:
# <style type="text/css">
# #T_09ccb_row8_col1, #T_09ccb_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_09ccb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09ccb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_09ccb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09ccb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09ccb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_09ccb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09ccb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_09ccb_row1_col1" class="data row1 col1" >pff_missedTackle</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09ccb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_09ccb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09ccb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_09ccb_row3_col1" class="data row3 col1" >(22945, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09ccb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_09ccb_row4_col1" class="data row4 col1" >(22945, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_09ccb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_09ccb_row5_col1" class="data row5 col1" >(16061, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_09ccb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_09ccb_row6_col1" class="data row6 col1" >(6884, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_09ccb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_09ccb_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_09ccb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_09ccb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_09ccb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_09ccb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_09ccb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_09ccb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_09ccb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_09ccb_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_09ccb_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_09ccb_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_09ccb_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_09ccb_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_09ccb_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_09ccb_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_09ccb_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_09ccb_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_09ccb_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_09ccb_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_09ccb_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_09ccb_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_09ccb_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_09ccb_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_09ccb_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_09ccb_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_09ccb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_09ccb_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_09ccb_row20_col1" class="data row20 col1" >5833</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_8350f th {
#   text-align: left;
# }
# #T_8350f_row0_col0, #T_8350f_row1_col0, #T_8350f_row1_col1, #T_8350f_row1_col2, #T_8350f_row1_col3, #T_8350f_row1_col4, #T_8350f_row1_col5, #T_8350f_row1_col6, #T_8350f_row1_col7, #T_8350f_row2_col0, #T_8350f_row2_col1, #T_8350f_row2_col2, #T_8350f_row2_col3, #T_8350f_row2_col4, #T_8350f_row2_col5, #T_8350f_row2_col6, #T_8350f_row2_col7, #T_8350f_row3_col0, #T_8350f_row3_col1, #T_8350f_row3_col2, #T_8350f_row3_col3, #T_8350f_row3_col4, #T_8350f_row3_col5, #T_8350f_row3_col6, #T_8350f_row3_col7, #T_8350f_row4_col0, #T_8350f_row4_col1, #T_8350f_row4_col2, #T_8350f_row4_col3, #T_8350f_row4_col4, #T_8350f_row4_col5, #T_8350f_row4_col6, #T_8350f_row4_col7, #T_8350f_row5_col0, #T_8350f_row5_col1, #T_8350f_row5_col2, #T_8350f_row5_col3, #T_8350f_row5_col4, #T_8350f_row5_col5, #T_8350f_row5_col6, #T_8350f_row5_col7, #T_8350f_row6_col0, #T_8350f_row6_col1, #T_8350f_row6_col2, #T_8350f_row6_col3, #T_8350f_row6_col4, #T_8350f_row6_col5, #T_8350f_row6_col6, #T_8350f_row6_col7, #T_8350f_row7_col0, #T_8350f_row7_col1, #T_8350f_row7_col2, #T_8350f_row7_col3, #T_8350f_row7_col4, #T_8350f_row7_col5, #T_8350f_row7_col6, #T_8350f_row7_col7, #T_8350f_row8_col0, #T_8350f_row8_col1, #T_8350f_row8_col2, #T_8350f_row8_col3, #T_8350f_row8_col4, #T_8350f_row8_col5, #T_8350f_row8_col6, #T_8350f_row8_col7, #T_8350f_row9_col0, #T_8350f_row9_col1, #T_8350f_row9_col2, #T_8350f_row9_col3, #T_8350f_row9_col4, #T_8350f_row9_col5, #T_8350f_row9_col6, #T_8350f_row9_col7, #T_8350f_row10_col0, #T_8350f_row10_col1, #T_8350f_row10_col2, #T_8350f_row10_col3, #T_8350f_row10_col4, #T_8350f_row10_col5, #T_8350f_row10_col6, #T_8350f_row10_col7, #T_8350f_row11_col0, #T_8350f_row11_col1, #T_8350f_row11_col2, #T_8350f_row11_col3, #T_8350f_row11_col4, #T_8350f_row11_col5, #T_8350f_row11_col6, #T_8350f_row11_col7, #T_8350f_row12_col0, #T_8350f_row12_col1, #T_8350f_row12_col2, #T_8350f_row12_col3, #T_8350f_row12_col4, #T_8350f_row12_col5, #T_8350f_row12_col6, #T_8350f_row12_col7, #T_8350f_row13_col0, #T_8350f_row13_col1, #T_8350f_row13_col2, #T_8350f_row13_col3, #T_8350f_row13_col4, #T_8350f_row13_col5, #T_8350f_row13_col6, #T_8350f_row13_col7, #T_8350f_row14_col0, #T_8350f_row14_col1, #T_8350f_row14_col2, #T_8350f_row14_col3, #T_8350f_row14_col4, #T_8350f_row14_col5, #T_8350f_row14_col6, #T_8350f_row14_col7, #T_8350f_row15_col0, #T_8350f_row15_col1, #T_8350f_row15_col2, #T_8350f_row15_col3, #T_8350f_row15_col4, #T_8350f_row15_col5, #T_8350f_row15_col6, #T_8350f_row15_col7 {
#   text-align: left;
# }
# #T_8350f_row0_col1, #T_8350f_row0_col2, #T_8350f_row0_col3, #T_8350f_row0_col4, #T_8350f_row0_col5, #T_8350f_row0_col6, #T_8350f_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8350f_row0_col8, #T_8350f_row1_col8, #T_8350f_row2_col8, #T_8350f_row3_col8, #T_8350f_row4_col8, #T_8350f_row5_col8, #T_8350f_row6_col8, #T_8350f_row7_col8, #T_8350f_row8_col8, #T_8350f_row9_col8, #T_8350f_row10_col8, #T_8350f_row12_col8, #T_8350f_row13_col8, #T_8350f_row14_col8, #T_8350f_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8350f_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8350f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8350f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8350f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8350f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8350f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8350f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8350f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8350f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8350f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8350f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8350f_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_8350f_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_8350f_row0_col1" class="data row0 col1" >0.9683</td>
#       <td id="T_8350f_row0_col2" class="data row0 col2" >0.9825</td>
#       <td id="T_8350f_row0_col3" class="data row0 col3" >0.8076</td>
#       <td id="T_8350f_row0_col4" class="data row0 col4" >0.8304</td>
#       <td id="T_8350f_row0_col5" class="data row0 col5" >0.8186</td>
#       <td id="T_8350f_row0_col6" class="data row0 col6" >0.8013</td>
#       <td id="T_8350f_row0_col7" class="data row0 col7" >0.8015</td>
#       <td id="T_8350f_row0_col8" class="data row0 col8" >6.0320</td>
#     </tr>
#     <tr>
#       <th id="T_8350f_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_8350f_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_8350f_row1_col1" class="data row1 col1" >0.9679</td>
#       <td id="T_8350f_row1_col2" class="data row1 col2" >0.9824</td>
#       <td id="T_8350f_row1_col3" class="data row1 col3" >0.8048</td>
#       <td id="T_8350f_row1_col4" class="data row1 col4" >0.8288</td>
#       <td id="T_8350f_row1_col5" class="data row1 col5" >0.8164</td>
#       <td id="T_8350f_row1_col6" class="data row1 col6" >0.7989</td>
#       <td id="T_8350f_row1_col7" class="data row1 col7" >0.7991</td>
#       <td id="T_8350f_row1_col8" class="data row1 col8" >0.6480</td>
#     </tr>
#     <tr>
#       <th id="T_8350f_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_8350f_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_8350f_row2_col1" class="data row2 col1" >0.9668</td>
#       <td id="T_8350f_row2_col2" class="data row2 col2" >0.9695</td>
#       <td id="T_8350f_row2_col3" class="data row2 col3" >0.7907</td>
#       <td id="T_8350f_row2_col4" class="data row2 col4" >0.8269</td>
#       <td id="T_8350f_row2_col5" class="data row2 col5" >0.8082</td>
#       <td id="T_8350f_row2_col6" class="data row2 col6" >0.7900</td>
#       <td id="T_8350f_row2_col7" class="data row2 col7" >0.7904</td>
#       <td id="T_8350f_row2_col8" class="data row2 col8" >0.4720</td>
#     </tr>
#     <tr>
#       <th id="T_8350f_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_8350f_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8350f_row3_col1" class="data row3 col1" >0.9665</td>
#       <td id="T_8350f_row3_col2" class="data row3 col2" >0.9823</td>
#       <td id="T_8350f_row3_col3" class="data row3 col3" >0.7921</td>
#       <td id="T_8350f_row3_col4" class="data row3 col4" >0.8235</td>
#       <td id="T_8350f_row3_col5" class="data row3 col5" >0.8072</td>
#       <td id="T_8350f_row3_col6" class="data row3 col6" >0.7888</td>
#       <td id="T_8350f_row3_col7" class="data row3 col7" >0.7892</td>
#       <td id="T_8350f_row3_col8" class="data row3 col8" >0.1520</td>
#     </tr>
#     <tr>
#       <th id="T_8350f_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_8350f_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_8350f_row4_col1" class="data row4 col1" >0.9663</td>
#       <td id="T_8350f_row4_col2" class="data row4 col2" >0.9815</td>
#       <td id="T_8350f_row4_col3" class="data row4 col3" >0.7823</td>
#       <td id="T_8350f_row4_col4" class="data row4 col4" >0.8281</td>
#       <td id="T_8350f_row4_col5" class="data row4 col5" >0.8041</td>
#       <td id="T_8350f_row4_col6" class="data row4 col6" >0.7856</td>
#       <td id="T_8350f_row4_col7" class="data row4 col7" >0.7863</td>
#       <td id="T_8350f_row4_col8" class="data row4 col8" >0.1940</td>
#     </tr>
#     <tr>
#       <th id="T_8350f_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_8350f_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_8350f_row5_col1" class="data row5 col1" >0.9652</td>
#       <td id="T_8350f_row5_col2" cla

# %%
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Aanlysis

# %%
import pickle
pickle.dump(model, open("../models/model_mott.pkl", 'wb'))

# %%
result_data = mott_features_data.copy()
result_data["prediction"] = model.predict(result_data.drop(columns=["pff_missedTackle"]))

# %%
result_data
# Out:
#                                 ott  mean_distance_to_ball_carrier_from_peak  \
# gameId     playId nflId
# 2022090800 56     38577.0  0.158333                                 1.971121
#                   41239.0  0.000607                                13.907379
#                   42816.0  0.001262                                27.279112
#                   43294.0  1.046483                                 0.670298
#                   43298.0  0.000308                                12.350122
# ...                             ...                                      ...
# 2022110700 3787   52627.0  0.012055                                13.470441
#                   53460.0  0.115559                                 4.405723
#                   53533.0  0.001109                                19.715603
#                   54541.0  1.136388                                 1.121133
#                   54606.0  0.005385                                12.675541
#
#                            ball_carrier_distance_won_to_last_frame  \
# gameId     playId nflId
# 2022090800 56     38577.0                                     0.00
#                   41239.0                                     0.00
#                   42816.0                                     0.52
#                   43294.0                                     0.00
#                   43298.0                                     1.15
# ...                                                            ...
# 2022110700 3787   52627.0                                     5.57
#                   53460.0                                     6.54
#                   53533.0                                     0.00
#                   54541.0                                     1.95
#                   54606.0                                     0.59
#
#                            tackle_or_assist  pff_missedTackle  prediction
# gameId     playId nflId
# 2022090800 56     38577.0               0.0               0.0         0.0
#                   41239.0               0.0               0.0         0.0
#                   42816.0               0.0               0.0         0.0
#                   43294.0               1.0               0.0         0.0
#                   43298.0               0.0               0.0         0.0
# ...                                     ...               ...         ...
# 2022110700 3787   52627.0               0.0               0.0         0.0
#                   53460.0               0.0               0.0         0.0
#                   53533.0               0.0               0.0         0.0
#                   54541.0               0.0               0.0         1.0
#                   54606.0               0.0               0.0         0.0
#
# [127941 rows x 6 columns]

# %%
result_data.loc[(2022100911,2915)]
# Out:
#               ott  mean_distance_to_ball_carrier_from_peak  \
# nflId
# 42401.0  0.000421                                19.369486
# 43986.0  0.795232                                 4.820028
# 44848.0  0.018716                                 8.442979
# 47816.0  1.076127                                 3.278709
# 47848.0  0.001377                                16.561179
# 49410.0  0.012372                                 9.991531
# 52416.0  0.605927                                 2.162725
# 52522.0  0.003440                                10.140932
# 53445.0  0.032192                                 5.606291
# 53565.0  0.000405                                21.414975
# 54552.0  0.052747                                 3.155725
#
#          ball_carrier_distance_won_to_last_frame  tackle_or_assist  \
# nflId
# 42401.0                                     7.07               0.0
# 43986.0                                     6.44               0.0
# 44848.0                                     1.66               0.0
# 47816.0                                     5.02               1.0
# 47848.0                                     7.89               0.0
# 49410.0                                     3.07               0.0
# 52416.0                                     3.48               0.0
# 52522.0                                     7.43               0.0
# 53445.0                                     0.00               0.0
# 53565.0                                     7.59               0.0
# 54552.0                                     0.00               0.0
#
#          pff_missedTackle  prediction
# nflId
# 42401.0               0.0         0.0
# 43986.0               1.0         1.0
# 44848.0               0.0         0.0
# 47816.0               0.0         1.0
# 47848.0               0.0         0.0
# 49410.0               0.0         0.0
# 52416.0               0.0         1.0
# 52522.0               0.0         0.0
# 53445.0               0.0         0.0
# 53565.0               0.0         0.0
# 54552.0               0.0         0.0
